# %% [markdown]
# # DATA CLEANING

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def wrangle(filepath):
  data = pd.read_excel(filepath)

  # Drop duplicate
  data.drop_duplicates(keep = False, inplace = True)
  return data

# %%
data_PerGame = wrangle("/content/drive/MyDrive/NBA_project/NBA_Project/data/Data_PerGame.xlsx")

display(data_PerGame.shape)
display(data_PerGame.head())
# Out:
# (735, 30)
#   Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0  1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  ...  .616
# 1  1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
# 2  1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  ...  .643
# 3  2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  ...  .755
# 4  3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  ...  .661
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %%
data_Shooting = wrangle("/content/drive/MyDrive/NBA_project/NBA_Project/data/Data_Shooting.xlsx")

display(data_Shooting.shape)
display(data_Shooting.head())
# Out:
# (735, 21)
#   Rk            Player   Pos Age   Tm   G    MP   FG% Dist.       ...   0-3  \
# 0  1  Precious Achiuwa  PF-C  24  TOT  74  1624  .501   7.6  NaN  ...  .697
# 1  1  Precious Achiuwa     C  24  TOR  25   437  .459   9.5  NaN  ...  .662
# 2  1  Precious Achiuwa    PF  24  NYK  49  1187  .525   6.5  NaN  ...  .711
# 3  2       Bam Adebayo     C  26  MIA  71  2416  .521   8.5  NaN  ...  .727
# 4  3      Ochai Agbaji    SG  23  TOT  78  1641  .411  14.0  NaN  ...  .664
#
#    3-10 10-16 16-3P     3P  %FGA  #  %3PA   3P% Att.
# 0  .317  .273  .200   .962  .145  0  .474  .304    0
# 1  .357  .250  .500  1.000  .147  0  .362  .294    0
# 2  .288  .286  .000   .923  .144  0  .580  .310    0
# 3  .515  .406  .386  1.000  .148  0  .167  .429    0
# 4  .329  .438  .200   .984  .085  0  .455  .365    1
#
# [5 rows x 21 columns]

# %%
data_Advance = wrangle("/content/drive/MyDrive/NBA_project/NBA_Project/data/Data_PerGame.xlsx")

display(data_Advance.shape)
display(data_Advance.head())
# Out:
# (735, 30)
#   Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0  1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  ...  .616
# 1  1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
# 2  1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  ...  .643
# 3  2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  ...  .755
# 4  3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  ...  .661
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %%
data_hof = wrangle("/content/drive/MyDrive/NBA_project/NBA_Project/data/Data_HOF.xlsx")

display(data_hof.shape)
display(data_hof.head())
# Out:
# (473, 18)
#    Year                                               Name     Category    G  \
# 0  2024       Seimone Augustus   WNBA / Int'l / CBB player       Player  NaN
# 1  2024                      Dick Barnett   Player / Coach       Player  NaN
# 2  2024  Chauncey Billups   Player / Coach / Int'l / CB...       Player  NaN
# 3  2024         Vince Carter   Player / Int'l / CBB player       Player  NaN
# 4  2024  Doug Collins   Player / Coach / Exec / Int'l /...  Contributor  NaN
#
#     PTS  TRB  AST  STL  BLK   FG%   3P%   FT%     WS WS/48  Unnamed: 14    W  \
# 0   NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN   NaN          NaN  NaN
# 1  15.8  2.9  2.8  0.2  0.0  .456   NaN  .761   68.7  .114          NaN  NaN
# 2  15.2  2.9  5.4  1.0  0.2  .415  .387  .894  120.8  .176          NaN  NaN
# 3  16.7  4.3  3.1  1.0  0.6  .435  .371  .798  125.3  .130          NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN   NaN          NaN  NaN
#
#      L W/L%
# 0  NaN  NaN
# ...

# %%
#######################################DON'T RUN#######################################
drop_row = []
for i in range(len(data_df['Rk'])):
    if data_df.iloc[i]['Rk'] == 'Rk':
        drop_row.append(i)
drop_row
data_df.drop(drop_row, inplace=True)
data_df.shape
# Out:
# (812, 30)

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# Examine the target dataset
data_hof['Category'].value_counts()
# Out:
# Category
# Player         236
# Coach          123
# Contributor     84
# Referee         17
# Team            13
# Name: count, dtype: int64

# %%
# Select only Category of Players
data_hof = data_hof[data_hof['Category'] == 'Player']
data_hof.shape
# Out:
# (236, 18)

# %%
# Examine the columns in the target dataset
data_hof.columns
# Out:
# Index(['Year', 'Name', 'Category', 'G', 'PTS', 'TRB', 'AST', 'STL', 'BLK',
#        'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Unnamed: 14', 'W', 'L', 'W/L%'],
#       dtype='object')

# %%
# Select the columns needed

selected_cols = ['PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48']
data_hof = data_hof[selected_cols]

data_hof.shape
# Out:
# (236, 10)

# %%
# Drop rows where all values are missing

data_hof = data_hof.dropna(how='all')

data_hof.shape
# Out:
# (152, 10)

# %%
data_hof.head()
# Out:
#     PTS  TRB  AST  STL  BLK   FG%   3P%   FT%     WS WS/48
# 1  15.8  2.9  2.8  0.2  0.0  .456   NaN  .761   68.7  .114
# 2  15.2  2.9  5.4  1.0  0.2  .415  .387  .894  120.8  .176
# 3  16.7  4.3  3.1  1.0  0.6  .435  .371  .798  125.3  .130
# 5   8.9  3.2  4.2  1.2  0.6  .469   NaN  .833   52.5  .107
# 6  18.9  3.0  3.8  1.2  0.1  .511   NaN  .851   76.9  .128

# %%
# Check muiltcolinearity

data_hof_cleaned = data_hof.drop(columns='PTS')
correlation_matrix = data_hof_cleaned.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# COmbine the three dataset together

combined_df = pd.concat([data_PerGame, data_Shooting, data_Advance], axis=1)

# Remove duplicate columns (if any)
combined_df = combined_df.loc[:, ~combined_df.columns.duplicated()]

display(combined_df.shape)
display(combined_df.head())
# Out:
# (735, 40)
#   Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ... Dist.  \
# 0  1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  ...   7.6
# 1  1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...   9.5
# 2  1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  ...   6.5
# 3  2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  ...   8.5
# 4  3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  ...  14.0
#
#          0-3  3-10 10-16 16-3P  %FGA  #  %3PA Att.
# 0  NaN  .697  .317  .273  .200  .145  0  .474    0
# 1  NaN  .662  .357  .250  .500  .147  0  .362    0
# 2  NaN  .711  .288  .286  .000  .144  0  .580    0
# 3  NaN  .727  .515  .406  .386  .148  0  .167    0
# 4  NaN  .664  .329  .438  .200  .085  0  .455    1
#
# [5 rows x 40 columns]

# %%
selected_cols = ['PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%']
combined_df = combined_df[selected_cols]

combined_df.head()
# Out:
#     PTS   TRB  AST  STL  BLK   FG%   3P%   FT%
# 0   7.6   6.6  1.3  0.6  0.9  .501  .268  .616
# 1   7.7   5.4  1.8  0.6  0.5  .459  .277  .571
# 2   7.6   7.2  1.1  0.6  1.1  .525  .260  .643
# 3  19.3  10.4  3.9  1.1  0.9  .521  .357  .755
# 4   5.8   2.8  1.1  0.6  0.6  .411  .294  .661

# %% [markdown]
# ## *Boostrapping*

# %%
def bootstrap_resample(df, n=None):
    """
    Bootstrap resample a DataFrame.

    Parameters:
    df (DataFrame): The original DataFrame.
    n (int): The number of samples to generate. If None, it will be the same as the original DataFrame.

    Returns:
    DataFrame: The resampled DataFrame.
    """
    if n is None:
        n = len(df)
    resample_i = np.random.randint(0, len(df), n)
    df_resample = df.iloc[resample_i].reset_index(drop=True)
    return df_resample

# %%
# Number of rows in the original dataset
original_rows = len(data_hof)

# Number of rows you want in the new dataset
target_rows = 1000  # For example, you want 100 rows

# Bootstrapping to increase the number of rows
df_bootstrapped = bootstrap_resample(data_hof, target_rows)

# Display the new DataFrame
df_bootstrapped.shape
# Out:
# (1000, 10)

# %%
df_bootstrapped.head()
# Out:
#     PTS   TRB  AST  STL  BLK   FG%   3P%   FT%     WS WS/48
# 0  30.1  22.9  4.4  NaN  NaN  .540   NaN  .511  247.3  .248
# 1  12.1   6.1  2.7  1.5  1.4  .560   NaN  .766   94.1  .175
# 2  14.5   9.1  1.4  0.8  1.5  .537   NaN  .721  147.0  .154
# 3  21.0   3.9  3.5  1.2  0.3  .455  .388  .850   79.3  .111
# 4  22.1  11.7  3.9  1.5  0.8  .541  .266  .735  177.2  .216

# %% [markdown]
# FOR THE HALL OF FAME DATA
# SELECT THE CATEGORY WITH UNIQUE VARIABLE PLAYER ONLY
# DROP SOME SELECTED COLUMN (category, empty W, L, W/L% and Year also)

# %%
FOR THE FIRST DATA
CHECK FOR DUPLICATE
REMOVE DUPLICATED ROW
REMOVE THE DUPLICATED COLUMN ALSO

# %%
FOR THE SECOND ENDPOINT DATA
CHECK FOR DUPLICATE
REMOVE DUPLICATED ROW
REMOVE THE DUPLICATED COLUMN ALSO

# %%
FOR THE THIRD ENDPOINT DATA
CHECK FOR DUPLICATE
REMOVE DUPLICATED ROW
REMOVE THE DUPLICATED COLUMN ALSO

# %%
# Out:
# (842, 30)
#   Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...  .595  2.0
# 1  2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...  .543  4.6
# 2  3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...  .753  2.4
# 3  4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...  .625  1.0
# 4  5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...  .873  1.6
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
#
# [5 rows x 30 columns]

# %%
#CHECK FOR DUPLICATE
data_PerGame.duplicated().sum()
# Out:
# 29

# %%
#DROP THE DUPLICATE ROW
data_PerGame.drop_duplicates(keep=False, inplace = True)

# %%
# Out:
# (812, 30)

# %%
# Out:
# (842, 19)
#   Rk             Player Pos Age   Tm   G    MP   FG% Dist.    2P   0-3  3-10  \
# 0  1   Precious Achiuwa   C  22  TOR  73  1725  .439  10.2  .598  .614  .345
# 1  2       Steven Adams   C  28  MEM  76  1999  .547   2.9  .490  .632  .350
# 2  3        Bam Adebayo   C  24  MIA  56  1825  .557   7.0  .608  .771  .467
# 3  4       Santi Aldama  PF  21  MEM  32   360  .402  12.0  .638  .682  .444
# 4  5  LaMarcus Aldridge   C  36  BRK  47  1050  .550  12.3  .748  .729  .513
#
#   10-16 16-3P     3P  %FGA  %3PA   3P% Att.
# 0  .373  .190   .964  .143  .429  .313    0
# 1  .438  .000    NaN  .143  .000   NaN    1
# 2  .404  .313    NaN  .181  .000   NaN    2
# 3  .417  .000  1.000  .076  .229  .364    0
# 4  .509  .563  1.000  .039  .283  .308    0

# %%
drop_columns = data_Shooting.columns
for col in drop_columns:
    if col == " ":
        data_Shooting.drop([col], axis = 1, inplace = True)
data_Shooting.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'FG%', 'Dist.', ' ',
#        '2P', '0-3', '3-10', '10-16', '16-3P', '3P', '%FGA', '%3PA', '3P%',
#        'Att.'],
#       dtype='object')

# %%
name = " "
name
# Out:
# ' '
